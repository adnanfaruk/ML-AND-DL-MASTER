# %% [markdown]
# In this assignment students have to transform iris data into 3 dimensions
# and plot a 3d chart with transformed dimensions and colour each data
# point with specific class.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn.decomposition import PCA
from sklearn import datasets
import seaborn as sns

# %%
data=sns.load_dataset('iris')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x=data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(x)
principlDf=pd.DataFrame(data=principalComponents,columns=['principal component 1', 'principal component 2', 'principal component 3'])

# %%
principlDf
# Out:
#      principal component 1  principal component 2  principal component 3
# 0                -2.684126               0.319397              -0.027915
# 1                -2.714142              -0.177001              -0.210464
# 2                -2.888991              -0.144949               0.017900
# 3                -2.745343              -0.318299               0.031559
# 4                -2.728717               0.326755               0.090079
# ..                     ...                    ...                    ...
# 145               1.944110               0.187532               0.177825
# 146               1.527167              -0.375317              -0.121898
# 147               1.764346               0.078859               0.130482
# 148               1.900942               0.116628               0.723252
# 149               1.390189              -0.282661               0.362910
#
# [150 rows x 3 columns]

# %%
principlDf.insert(3,'Species',data['species'].values)

# %%
principlDf
# Out:
#      principal component 1  principal component 2  principal component 3  \
# 0                -2.684126               0.319397              -0.027915
# 1                -2.714142              -0.177001              -0.210464
# 2                -2.888991              -0.144949               0.017900
# 3                -2.745343              -0.318299               0.031559
# 4                -2.728717               0.326755               0.090079
# ..                     ...                    ...                    ...
# 145               1.944110               0.187532               0.177825
# 146               1.527167              -0.375317              -0.121898
# 147               1.764346               0.078859               0.130482
# 148               1.900942               0.116628               0.723252
# 149               1.390189              -0.282661               0.362910
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# ...

# %%
principlDf['Species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: Species, dtype: int64

# %%
fig=plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('principal component 1')
ax.set_ylabel('principal component 2')
ax.set_zlabel('principal component 3')
ax.set_title('$3 dimensions $')

Species=['setosa','versicolor','virginica']
colors=['r','g','b']

for Specie,color in zip(Species,colors):
    indicestokeep=principlDf['Species']==Specie
    ax.scatter(principlDf.loc[indicestokeep,'principal component 1'],
               principlDf.loc[indicestokeep,'principal component 2'],
               principlDf.loc[indicestokeep,'principal component 3'], c=color,s=50)
    ax.legend(Species)
    ax.grid()
